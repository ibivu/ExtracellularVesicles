# %% [markdown]
# This notebook includes studies:
#
# - Plasma (2018): https://doi.org/10.1007/s00018-018-2773-4 (1187 proteins) [not in our training data]
# - CSF (2020): https://doi.org/10.3390/cells9091959 (687 proteins) [not in our training data]
# - Urine (2020):  https://doi.org/10.1080/20013078.2020.1736935 [not in our training data]
#
# Output datasets:
# - validation_all.csv
# - validation_nonoverlapping.csv

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

import pickle
from matplotlib_venn import venn2, venn3
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import RobustScaler

# %matplotlib inline

# %% [markdown]
# # Define paths

# %%
#user = 'kathi'
user = 'DeaGogishvili'

Data_path = '/Users/' + user + '/Documents/GitHub/ExtracellularVesicles/Data'

# %% [markdown]
# # Import data sets

# %% [markdown]
# ### 3 Studies combined

# %%
# load raw Vesiclepedia datasets
validation_data = Data_path + '/Validation/validation_dataset.csv'
validation_data = pd.read_csv(validation_data, sep=',', engine='python', squeeze=True)

# %%
def keep_first(ID):
    if ";" in ID:
        first_ID, _ = ID.split(";", 1)
        return first_ID
    else:
        return ID
    
validation_data_clean = validation_data.apply(func=keep_first)

# %%
# Make a list of proteins found in 3 studies
validation_list = set(validation_data_clean)
len(validation_list)
# Out:
# 2804

# %% [markdown]
# ### Unfiltered feature data set

# %%
df_all_no_filtering = Data_path + '/MachineLearning/training_data_no_filtering.csv' 
df_all_no_filtering = pd.read_csv(df_all_no_filtering)

df_all = Data_path + '/MachineLearning/training_data.csv' 
df_all = pd.read_csv(df_all, sep=',', engine='python')

# %% [markdown]
# ### Human Proteome

# %%
# load human proteome
human_proteome = Data_path + '/Curated/features_human_proteome_no_filtering.csv'
human_proteome = pd.read_csv(human_proteome, sep=',', engine='python')

# %%
# select overlapping proteins
validation_dataset = human_proteome[human_proteome['id'].isin(validation_list)]
len(validation_dataset['id'])
# make it look alike
validation_dataset = validation_dataset.drop(['fasta_sequence'], axis=1)
validation_dataset['EV'] = 1

# %% [markdown]
# ### Out Positive and negative Datasets

# %%
# load human proteome
training_data = Data_path + '/MachineLearning/training_data.csv'
training_data = pd.read_csv(training_data, sep=',', engine='python')

# %%
# Select proteins that are not in our training data
training_data_list = list(training_data['id'])
non_overlapping = validation_dataset[~validation_dataset['id'].isin(training_data_list)]
len(non_overlapping['id'])
# Out:
# 131

# %%
# # Save
# validation_dataset.to_csv(Data_path + '/validation/validation_all.csv', index=False)
# non_overlapping.to_csv(Data_path + '/validation/validation_nonoverlapping.csv', index=False)

# %%
validation_dataset
# Out:
#            id     length  hydr_count  polar_count  molecular_weight     helix  \
# 4      P62736   8.558421    0.427056     0.379310         15.574035  0.445623
# 11     P02655   6.658211    0.425743     0.386139         13.675570  0.623762
# 16     O75882  10.480790    0.426172     0.363891         17.491370  0.066480
# 18     P56385   6.108524    0.434783     0.420290         13.160801  0.753623
# 25     P04920  10.277287    0.419823     0.363417         17.281759  0.401289
# ...       ...        ...         ...          ...               ...       ...
# 20319  Q9H788   8.826548    0.352423     0.473568         15.893808  0.180617
# 20324  Q9BTW9  10.219169    0.467282     0.373322         17.233049  0.700503
# 20341  Q9NY65   8.810572    0.434298     0.398664         15.827793  0.436526
# 20346  P60174   7.960002    0.433735     0.377510         14.926271  0.461847
# 20364  P59665   6.554589    0.574468     0.287234         13.535769  0.000000
#
# ...

# %%
non_overlapping
# Out:
#            id     length  hydr_count  polar_count  molecular_weight     helix  \
# 289    Q86UW7  10.339850    0.415895     0.421296         17.384120  0.509259
# 534    P23560   7.948367    0.392713     0.421053         14.976942  0.064777
# 775    Q9NRL3   9.556506    0.369190     0.382470         16.522513  0.122178
# 821    Q5VY43  10.018200    0.350048     0.324012         16.980672  0.031823
# 871    Q9P270   9.182394    0.282272     0.373494         16.155354  0.049914
# ...       ...        ...         ...          ...               ...       ...
# 18818  Q6J9G0   8.721099    0.466825     0.353081         15.751317  0.338863
# 18980  Q9Y259   8.625709    0.422785     0.372152         15.676377  0.440506
# 19229  Q8IY42   8.294621    0.312102     0.436306         15.265081  0.165605
# 19802  Q14088   7.888743    0.430380     0.409283         14.912650  0.312236
# 20009  P0C0L5  10.768184    0.413417     0.373280         17.774049  0.212729
#
# ...

# %% [markdown]
# # Does the feature importance trend hold in a cleaner dataset?

# %%
# Combine datasets
validation_dataset['EV'] = 2
df_concat = pd.concat([df_all, validation_dataset])

# %% [markdown]
# # Calculate Significance

# %%
features_continuous = ['length', 'hydr_count', 'polar_count', 'molecular_weight',
       'helix', 'turn', 'sheet', 'A', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'K',
       'L', 'M', 'N', 'P', 'Q', 'R', 'S', 'T', 'V', 'W', 'Y', 'thsa_netsurfp2',
       'tasa_netsurfp2', 'rhsa_netsurfp2', 'disorder', 'A_exposed',
       'C_exposed', 'D_exposed', 'E_exposed', 'F_exposed', 'G_exposed',
       'H_exposed', 'I_exposed', 'K_exposed', 'L_exposed', 'M_exposed',
       'N_exposed', 'P_exposed', 'Q_exposed', 'R_exposed', 'S_exposed',
       'T_exposed', 'V_exposed', 'W_exposed', 'Y_exposed',
       'Prob. of Solubility', 'Aggregation_propensity', 'Aromaticity',
       'Instability_index', 'Gravy', 'isoelectric_point', 'charge_at_7',
       'charge_at_5', 'Polar_exposed', 'Hydrophobic_exposed']

features_categorical = ['HSP', 'PTM_UP', 'Citrullination_UP', 'GPI-anchor_UP',
       'Lipoprotein_UP', 'Nitration_UP', 'Prenylation_UP', 'ISGylation_UP',
       'NEDDylation_UP', 'Acetylation_all', 'Glycosylation_all',
       'Methylation_all', 'Myristoylation_all', 'Nitrosylation_all',
       'Palmitoylation_all', 'Phosphorylation_all', 'SUMOylation_all',
       'Ubiquitination_all', 'PTM_MSD', 'Phosphorylation_MSD',
       'Glycosylation_MSD', 'Ubiquitination_MSD', 'SUMOylation_MSD',
       'Acetylation_MSD', 'Palmitoylation_MSD', 'Methylation_MSD',
       'coiled_coil', 'RAS_profile', 'ww_domain', 'EGF', 'RRM', 'transmembrane', 'TMHMM']

EV_yes = df_concat[df_concat["EV"] == 1]
EV_no = df_concat[df_concat["EV"] == 0]
Validation_EVs = df_concat[df_concat["EV"] == 2]

# %%
# Mann-Whitney U test
from scipy.stats import mannwhitneyu, chi2_contingency, fisher_exact
from statsmodels.stats.multitest import fdrcorrection

# create Series to save p-values
p_vals = pd.Series(index=features_continuous, dtype="float64", name='p_value')

# calculate p-values using Mann-Whitney U Test
for i, feature in enumerate(features_continuous):
    
    stat, p = mannwhitneyu(EV_yes[feature], Validation_EVs[feature]) # function return statistic and p-value
    p_vals[i] = p 

# calculate adjusted p-value (FDR correction)
rejected, p_vals_adj = fdrcorrection(p_vals)
# create Series to save adjusted p-values
p_vals_adj = pd.Series(data=p_vals_adj, index=features_continuous, name='p_value_adjusted')

# save both p-values in dataframe
p_vals_comb = pd.concat([p_vals, p_vals_adj], axis=1)
# sort by adjusted p-value
p_vals_comb = p_vals_comb.sort_values(by='p_value_adjusted')

# print adjusted p-values (readable)
for i in range(len(p_vals_comb)):
    print(p_vals_comb.index[i], 'p=%.5f' % (p_vals_comb.p_value_adjusted[i]))
# Out:
# Instability_index p=0.00000
# disorder p=0.00000
# charge_at_5 p=0.00000
# turn p=0.00000
# tasa_netsurfp2 p=0.00000
# thsa_netsurfp2 p=0.00000
# R p=0.00000
# V p=0.00000
# Aggregation_propensity p=0.00000
# hydr_count p=0.00000
# H p=0.00000
# P p=0.00000
# S p=0.00000
# isoelectric_point p=0.00000
# Gravy p=0.00000
# I p=0.00000
# D_exposed p=0.00000
# H_exposed p=0.00000
# molecular_weight p=0.00000
# length p=0.00000
# S_exposed p=0.00000
# P_exposed p=0.00000
# Aromaticity p=0.00000
# Polar_exposed p=0.00000
# helix p=0.00000
# R_exposed p=0.00000
# charge_at_7 p=0.00000
# K_exposed p=0.00000
# C_exposed p=0.00000
# Y p=0.00000
# E_exposed p=0.00000
# sheet p=0.00000
# D p=0.00000
# F p=0.00000
# L_exposed p=0.00000
# A p=0.00000
# N_exposed p=0.00000
# T p=0.00000
# M p=0.00004
# Hydrophobic_exposed p=0.00071
# Q p=0.00088
# V_exposed p=0.00213
# N p=0.00229
# G p=0.00319
# K p=0.02417
# C p=0.03040
# W p=0.03567
# polar_count p=0.04105
# Prob. of Solubility p=0.05179
# ...

# %%
# Mann-Whitney U test
from scipy.stats import mannwhitneyu, chi2_contingency, fisher_exact
from statsmodels.stats.multitest import fdrcorrection

# create Series to save p-values
p_vals = pd.Series(index=features_continuous, dtype="float64", name='p_value')

# calculate p-values using Mann-Whitney U Test
for i, feature in enumerate(features_continuous):
    
    stat, p = mannwhitneyu(EV_no[feature], Validation_EVs[feature]) # function return statistic and p-value
    p_vals[i] = p 

# calculate adjusted p-value (FDR correction)
rejected, p_vals_adj = fdrcorrection(p_vals)
# create Series to save adjusted p-values
p_vals_adj = pd.Series(data=p_vals_adj, index=features_continuous, name='p_value_adjusted')

# save both p-values in dataframe
p_vals_comb = pd.concat([p_vals, p_vals_adj], axis=1)
# sort by adjusted p-value
p_vals_comb = p_vals_comb.sort_values(by='p_value_adjusted')

# print adjusted p-values (readable)
for i in range(len(p_vals_comb)):
    print(p_vals_comb.index[i], 'p=%.5f' % (p_vals_comb.p_value_adjusted[i]))
# Out:
# Instability_index p=0.00000
# turn p=0.00000
# D_exposed p=0.00000
# disorder p=0.00000
# Polar_exposed p=0.00000
# charge_at_7 p=0.00000
# S p=0.00000
# V p=0.00000
# isoelectric_point p=0.00000
# H p=0.00000
# D p=0.00000
# I p=0.00000
# E_exposed p=0.00000
# P p=0.00000
# K_exposed p=0.00000
# sheet p=0.00000
# L_exposed p=0.00000
# S_exposed p=0.00000
# C_exposed p=0.00000
# R p=0.00000
# H_exposed p=0.00000
# C p=0.00000
# Hydrophobic_exposed p=0.00000
# N_exposed p=0.00000
# hydr_count p=0.00000
# P_exposed p=0.00000
# charge_at_5 p=0.00000
# Gravy p=0.00000
# N p=0.00000
# R_exposed p=0.00000
# helix p=0.00000
# K p=0.00000
# rhsa_netsurfp2 p=0.00000
# W_exposed p=0.00000
# A p=0.00000
# Y p=0.00000
# V_exposed p=0.00000
# M p=0.00000
# F_exposed p=0.00000
# G p=0.00000
# Y_exposed p=0.00000
# T p=0.00000
# length p=0.00000
# molecular_weight p=0.00000
# Aggregation_propensity p=0.00000
# I_exposed p=0.00000
# Aromaticity p=0.00000
# thsa_netsurfp2 p=0.00000
# Q p=0.00000
# ...

# %%
# Fisher's exact test

# create Series to save p-values
p_vals_cat = pd.Series(index=features_categorical, dtype="float64", name='p_value')

# calculate p-values using Fisher's exact test
for i, feature in enumerate(features_categorical):
    
    # get counts for each category
    A = sum(EV_yes[feature]) # EV & positive
    B = len(EV_yes[feature]) - sum(EV_yes[feature]) # EV & negative
    C = sum(Validation_EVs[feature]) # no EV & positive
    D = len(Validation_EVs[feature]) - sum(Validation_EVs[feature]) # no EV & negative
    
    # create 2x2 contingency table of counts
    table = np.array([[A, B],
                      [C, D]])
    
    odds, p = fisher_exact(table, alternative='two-sided') # function return odds ratio and p-value
    p_vals_cat[i] = p 

# calculate adjusted p-value (FDR correction)
rejected, p_vals_adj_cat = fdrcorrection(p_vals_cat)
# create Series to save adjusted p-values
p_vals_adj_cat = pd.Series(data=p_vals_adj_cat, index=features_categorical, name='p_value_adjusted')

# save both p-values in dataframe
p_vals_comb_cat = pd.concat([p_vals_cat, p_vals_adj_cat], axis=1)
# sort by adjusted p-value
p_vals_comb_cat = p_vals_comb_cat.sort_values(by='p_value_adjusted')

# print adjusted p-values (readable)
for i in range(len(p_vals_comb_cat)):
    print(p_vals_comb_cat.index[i], 'p=%.5f' % (p_vals_comb_cat.p_value_adjusted[i]))
# Out:
# Palmitoylation_all p=0.00000
# Nitrosylation_all p=0.00000
# RRM p=0.00000
# Acetylation_all p=0.00000
# PTM_UP p=0.00000
# Acetylation_MSD p=0.00000
# Methylation_MSD p=0.00000
# Lipoprotein_UP p=0.00000
# Prenylation_UP p=0.00000
# RAS_profile p=0.00000
# Phosphorylation_MSD p=0.00003
# coiled_coil p=0.00015
# transmembrane p=0.00082
# Ubiquitination_all p=0.00082
# SUMOylation_MSD p=0.00126
# ISGylation_UP p=0.00216
# Methylation_all p=0.00848
# Myristoylation_all p=0.00944
# Glycosylation_MSD p=0.03204
# SUMOylation_all p=0.18757
# EGF p=0.22837
# TMHMM p=0.22837
# NEDDylation_UP p=0.22837
# Nitration_UP p=0.23153
# Citrullination_UP p=0.36716
# PTM_MSD p=0.39104
# HSP p=0.39104
# GPI-anchor_UP p=0.42199
# Palmitoylation_MSD p=0.47213
# Glycosylation_all p=0.59863
# Ubiquitination_MSD p=0.61288
# ww_domain p=0.79511
# Phosphorylation_all p=0.80458

# %%
# Fisher's exact test

# create Series to save p-values
p_vals_cat = pd.Series(index=features_categorical, dtype="float64", name='p_value')

# calculate p-values using Fisher's exact test
for i, feature in enumerate(features_categorical):
    
    # get counts for each category
    A = sum(EV_no[feature]) # EV & positive
    B = len(EV_no[feature]) - sum(EV_no[feature]) # EV & negative
    C = sum(Validation_EVs[feature]) # no EV & positive
    D = len(Validation_EVs[feature]) - sum(Validation_EVs[feature]) # no EV & negative
    
    # create 2x2 contingency table of counts
    table = np.array([[A, B],
                      [C, D]])
    
    odds, p = fisher_exact(table, alternative='two-sided') # function return odds ratio and p-value
    p_vals_cat[i] = p 

# calculate adjusted p-value (FDR correction)
rejected, p_vals_adj_cat = fdrcorrection(p_vals_cat)
# create Series to save adjusted p-values
p_vals_adj_cat = pd.Series(data=p_vals_adj_cat, index=features_categorical, name='p_value_adjusted')

# save both p-values in dataframe
p_vals_comb_cat = pd.concat([p_vals_cat, p_vals_adj_cat], axis=1)
# sort by adjusted p-value
p_vals_comb_cat = p_vals_comb_cat.sort_values(by='p_value_adjusted')

# print adjusted p-values (readable)
for i in range(len(p_vals_comb_cat)):
    print(p_vals_comb_cat.index[i], 'p=%.5f' % (p_vals_comb_cat.p_value_adjusted[i]))
# Out:
# Palmitoylation_all p=0.00000
# PTM_UP p=0.00000
# Acetylation_all p=0.00000
# Nitrosylation_all p=0.00000
# Ubiquitination_all p=0.00000
# Methylation_all p=0.00000
# Acetylation_MSD p=0.00000
# Phosphorylation_all p=0.00000
# Lipoprotein_UP p=0.00000
# Prenylation_UP p=0.00000
# RAS_profile p=0.00000
# Glycosylation_all p=0.00000
# ISGylation_UP p=0.00000
# Ubiquitination_MSD p=0.00000
# Myristoylation_all p=0.00000
# Nitration_UP p=0.00000
# SUMOylation_MSD p=0.00000
# HSP p=0.00000
# transmembrane p=0.00001
# EGF p=0.00004
# RRM p=0.00078
# SUMOylation_all p=0.00521
# Glycosylation_MSD p=0.00521
# GPI-anchor_UP p=0.00522
# ww_domain p=0.03370
# Citrullination_UP p=0.10707
# PTM_MSD p=0.33559
# Methylation_MSD p=0.36610
# coiled_coil p=0.77898
# NEDDylation_UP p=0.83281
# TMHMM p=0.92675
# Phosphorylation_MSD p=0.97602
# Palmitoylation_MSD p=0.97602

# %% [markdown]
# # Plot

# %%
# figure settings
sns.set(style=("ticks"), font_scale=1.2)
x1, x2, x3 = 0, 1, 2 
my_pal = {2: "lightcyan", 1: "cornflowerblue", 0: "darkblue"}
labels = ["Validation EV", "EV", "non-EV"]

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=False, figsize=(18, 4))

#################### plot 1 #######################

sns.violinplot(x="EV", y="molecular_weight", data=df_concat, ax=ax1, order=[2, 1, 0], palette=my_pal)
ax1.set(ylabel=None, xlabel=None, title="Molecular weight", xticklabels=(labels), ylim=(10, 25))
y, h, col = df_concat['molecular_weight'].max() + 0.8, 1, 'k'
ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax1.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['molecular_weight'].max() + 2.1, 1, 'k'
ax1.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax1.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#################### plot 2 #######################

sns.violinplot(x="EV", y="Instability_index", data=df_concat, ax=ax2, order=[2, 1, 0], palette=my_pal)
ax2.set(ylabel=None, xlabel=None, title="Instability index", xticklabels=(labels), ylim=(-30, 260))
y, h, col = df_concat['Instability_index'].max() + 5, 15, 'k'
ax2.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax2.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['Instability_index'].max() + 30, 15, 'k'
ax2.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax2.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)


#################### plot 3 #######################

sns.violinplot(x="EV", y="isoelectric_point", data=df_concat, ax=ax3, order=[2, 1, 0], palette=my_pal)
ax3.set(ylabel=None, xlabel=None, title="Isoelectric point", xticklabels=(labels), ylim=(3, 16.5))

y, h, col = df_concat['isoelectric_point'].max() + 1, 0.8, 'k'
ax3.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax3.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['isoelectric_point'].max() + 2.3, 0.8, 'k'
ax3.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax3.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#################### plot 4 #######################

sns.violinplot(x="EV", y="rhsa_netsurfp2", data=df_concat, ax=ax4, order=[2, 1, 0], palette=my_pal)
ax4.set(ylabel=None, xlabel=None, title="Relative hydrophobic surface area", xticklabels=(labels), ylim=(0, 1))
y, h, col = df_all['rhsa_netsurfp2'].max() + 0.05, 0.06, 'k'
ax4.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax4.text((x1+x2)*.5, y+h, "n.s.", ha='center', va='bottom', color=col)

y, h, col = df_all['rhsa_netsurfp2'].max() + 0.15, 0.06, 'k'
ax4.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax4.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#fig.savefig(Figure_path + '/Validation_1.JPEG', dpi=300, bbox_inches='tight')
# Out:
# Text(1.0, 0.9060647618893627, '***')

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True, figsize=(18, 4))
plt.ylim((-0.2, 1.4))

#################### plot 1 #######################

sns.violinplot(x="EV", y="helix", data=df_concat, ax=ax1, order=[2, 1, 0], palette=my_pal)
ax1.set(ylabel=None, xlabel=None, title="Alpha helix", xticklabels=(labels))

y, h, col = df_concat['helix'].max() + 0.1, 0.04, 'k'
ax1.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax1.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)
y, h, col = df_concat['helix'].max() + 0.19, 0.08, 'k'
ax1.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax1.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#################### plot 2 #######################

sns.violinplot(x="EV", y="sheet", data=df_concat, ax=ax2, order=[2, 1, 0], palette=my_pal)
ax2.set(ylabel=None, xlabel=None, title="Beta sheet", xticklabels=(labels))

y, h, col = df_concat['sheet'].max() + 0.15, 0.1, 'k'
ax2.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax2.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['sheet'].max() + 0.35, 0.1, 'k'
ax2.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax2.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#################### plot 3 #######################

sns.violinplot(x="EV", y="turn", data=df_concat, ax=ax3, order=[2, 1, 0], palette=my_pal)
ax3.set(ylabel=None, xlabel=None, title="Turn", xticklabels=(labels))

y, h, col = df_concat['turn'].max() + 0.08, 0.06, 'k'
ax3.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax3.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['turn'].max() + 0.19, 0.08, 'k'
ax3.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax3.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#################### plot 4 #######################

sns.violinplot(x="EV", y="disorder", data=df_concat, ax=ax4, order=[2, 1, 0], palette=my_pal)
ax4.set(ylabel=None, xlabel=None, title="Disorder", xticklabels=(labels));

y, h, col = df_concat['disorder'].max() + 0.08, 0.06, 'k'
ax4.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
ax4.text((x1+x2)*.5, y+h, "***", ha='center', va='bottom', color=col)

y, h, col = df_concat['disorder'].max() + 0.19, 0.08, 'k'
ax4.plot([x1, x1, x3, x3], [y, y+h, y+h, y], lw=1.5, c=col)
ax4.text((x1+x3)*.5, y+h, "***", ha='center', va='bottom', color=col)

#fig.savefig(Figure_path + '/Validation_2.JPEG', dpi=300, bbox_inches='tight')
# Out:
# Text(1.0, 1.27, '***')

# %%
# figure settings
sns.set(style=("ticks"), font_scale=1.2)
x1, x2, x3 = 0, 1, 2 
my_pal = {2: "lightcyan", 1: "cornflowerblue", 0: "darkblue"}
labels = ["Validation EV", "EV", "non-EV"]

def annot_stat(star, x1, x2, y, h, col='k', ax=None):
    ax = plt.gca() if ax is None else ax
    ax.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.5, c=col)
    ax.text((x1+x2)*.5, y+h, star, ha='center', va='bottom', color=col)

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, sharey=True, figsize=(18, 4))
plt.ylim((0, 1.1))

sns.barplot(x="EV", y="PTM_UP", data=df_concat, ax=ax1, order=[2, 1, 0], palette=my_pal, edgecolor="black", ci=None)
ax1.set(ylabel=None, xlabel=None, title="All PTMs", xticklabels=(labels))

annot_stat('***', 0, 1, 0.9, 0.02, ax=ax1)
annot_stat('***', 0, 2, 0.98 , 0.03, ax=ax1)

sns.barplot(x="EV", y="Palmitoylation_all", data=df_concat, ax=ax2, order=[2, 1, 0], palette=my_pal, edgecolor="black", ci=None)
ax2.set(ylabel=None, xlabel=None, title="Palmitoylation", xticklabels=(labels))

annot_stat('***', 0, 1, 0.6, 0.03, ax=ax2)
annot_stat('***', 0, 2, 0.7, 0.03, ax=ax2)

sns.barplot(x="EV", y="Acetylation_all", data=df_concat, ax=ax3, order=[2, 1, 0], palette=my_pal, edgecolor="black", ci=None)
ax3.set(ylabel=None, xlabel=None, title="Acetylation", xticklabels=(labels))

annot_stat('***', 0, 1, 0.7, 0.03, ax=ax3)
annot_stat('***', 0, 2, 0.8, 0.03, ax=ax3)

sns.barplot(x="EV", y="Methylation_all", data=df_concat, ax=ax4, order=[2, 1, 0], palette=my_pal, edgecolor="black", ci=None)
ax4.set(ylabel=None, xlabel=None, title="Methylation", xticklabels=(labels));

annot_stat('***', 0, 1, 0.5, 0.03, ax=ax4)
annot_stat('***', 0, 2, 0.6, 0.03, ax=ax4)

#fig.savefig(Figure_path + '/Validation_3_PTMs.JPEG', dpi=300, bbox_inches='tight')
